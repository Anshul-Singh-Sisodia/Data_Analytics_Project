# %%
#Diabetes dataset

# %%
shape, describe, info, isna,
fillna(mean, median, mode)univariate and bivariate analysis, 
visualization(different plots), Algorithms--regression analysis (linear), OLS method,
Logistic regression, SVC, Naivebayes, Decision Tree, 
Random Forest, KNN, Kmeans ALgo, HC, Aproiori

# %%
#first we will load the dataset
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\classes\\B\\diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape #finding the no of rows or columns
# Out:
# (768, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#replace the missing values as true and non missing values as false
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
#identifying  the columns  having atleast  one missing value
df.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
df.notnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           True     True           True           True     True  True
# 1           True     True           True           True     True  True
# 2           True     True           True           True     True  True
# 3           True     True           True           True     True  True
# 4           True     True           True           True     True  True
# ..           ...      ...            ...            ...      ...   ...
# 763         True     True           True           True     True  True
# 764         True     True           True           True     True  True
# 765         True     True           True           True     True  True
# 766         True     True           True           True     True  True
# 767         True     True           True           True     True  True
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                        True  True     True
# ...

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Visualizing the data

# %%
#display the above info in a bar plot
import seaborn as sns
sns.countplot(x=df['Outcome'])
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
X=[2,3,4,5,6,7]
Y=[10,20,30,40,50,60]
plt.plot(X,Y,color='purple',linewidth=10,linestyle="dashed")
plt.title("LINE PLOT",color='red',fontsize=20)
plt.xlabel("X value",color='green',fontsize=20)
plt.ylabel("Y value",color='blue',fontsize=20)
plt.legend(["REGRESSION LINE "])
plt.grid(color="green",linewidth=2,linestyle=':')
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
Diseases=["Preg","Glu","Bp","SkinT","Insulin","BMI","Diabetes"]
levels=10,30,40,50,60,46,80
plt.pie(levels,labels=Diseases,autopct="%0.2f%%",\
        colors=['red','green','yellow'],shadow=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linewidth=5)
# Out:
# <Axes: >

# %%
#separate input and output
X=df.drop(columns=['Outcome'])
Y=df['Outcome']

# %%
from sklearn.linear_model import LogisticRegression
L=LogisticRegression()
#train the model
L.fit(X_train,Y_train)
#test the model
Y_pred_lg=L.predict(X_test)
#find accuracy
from sklearn.metrics import accuracy_score
acc_lg=accuracy_score(Y_test,Y_pred_lg)
acc_lg=round(acc_lg*100,2)
print("accuracy in logistic reg is",acc_lg,"%")
# Out:
# accuracy in logistic reg is 78.57 %
# C:\Users\DELL\anaconda4\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Implement decision tree algorithm
from sklearn.tree import DecisionTreeClassifier
D=DecisionTreeClassifier()
#train the model
D.fit(X_train,Y_train)
#test the model
Y_pred_dt=D.predict(X_test)
from sklearn.metrics import accuracy_score
acc_dt=accuracy_score(Y_test,Y_pred_dt)
acc_dt=round(acc_dt*100,2)
print("accuracy in decision tree is",acc_dt,"%")
# Out:
# accuracy in decision tree is 68.18 %

# %%
# Implement Naive bayes model
from sklearn.naive_bayes import GaussianNB
N=GaussianNB()
#train the model
N.fit(X_train,Y_train)
#test the model
Y_pred_nb=N.predict(X_test)
from sklearn.metrics import accuracy_score
acc_nb=accuracy_score(Y_test,Y_pred_nb)
acc_nb=round(acc_nb*100,2)
print("accuracy  in naive bayes is",acc_nb,"%")
# Out:
# accuracy  in naive bayes is 76.62 %

# %%
from sklearn.neighbors import KNeighborsClassifier
K=KNeighborsClassifier(n_neighbors=5)
# train the model by 80% of data
K.fit(X_train,Y_train)
#test the model
Y_pred=K.predict(X_test)
# find accuracy 
from sklearn.metrics import accuracy_score
acc_knn=accuracy_score(Y_test,Y_pred)
acc_knn=round(acc_knn*100,2)
print("acccuracy in KNN model is",acc_knn,"%")
# Out:
# acccuracy in KNN model is 71.43 %
